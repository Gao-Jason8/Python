# %% [markdown]
# <a href="https://colab.research.google.com/github/Gao-Jason8/Python/blob/main/01_Intro_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
multi = 2 * 14
print(f'2 * 14 is: {multi}')
# Out:
# 2 * 14 is: 28
